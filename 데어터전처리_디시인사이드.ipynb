# %%
# moduel import
import time
import requests, re
from bs4 import BeautifulSoup
from IPython.core.display import display, HTML
import nltk
from konlpy.tag import Okt
#from wordcloud import WordCloud
#from collections import Counter
import pandas as pd 
 
#봇 차단을 위한 헤더 설정
headers = {
    "Connection" : "keep-alive",
    "Cache-Control" : "max-age=0",
    "sec-ch-ua-mobile" : "?0",
    "DNT" : "1",
    "Upgrade-Insecure-Requests" : "1",
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36",
    "Accept" : "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "Sec-Fetch-Site" : "none",
    "Sec-Fetch-Mode" : "navigate",
    "Sec-Fetch-User" : "?1",
    "Sec-Fetch-Dest" : "document",
    "Accept-Encoding" : "gzip, deflate, br",
    "Accept-Language" : "ko-KR,ko;q=0.9"
    }
# Out:
# /var/folders/r6/7rzr78z90p953xj0yd90yt3r0000gn/T/ipykernel_1948/1975196032.py:5: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
enfj = [] #0
entj = [] #1
estj = [] #2
esfj = [] #3
entp = [] #4
enfp = [] #5
estp = [] #6
esfp = [] #7
istj = [] #8
isfj = [] #9
infj = [] #10
intj = [] #11
istp = [] #12
isfp = [] #13
infp = [] #14
intp = [] #15

# %% [markdown]
# ## ENFJ

# %%
for i in range(2,402):
    dc_id = "enfj&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text

        enfj.append(title)

# %%
enfj
# Out:
# ['밥먹는거 취소했다',
#  '가슴 뛰는 꿈이있으신가요?',
#  '이거 내가 문제인거지? (이성문제)',
#  '엔프제는 언제 이별을 결심함???',
#  '대놓고 마음확인하려고 하는 질문 별로야?',
#  '엔프제 오지랖도 필요할때만 조절해야지 완벽한듯',
#  '엔프제들 상대가 너네한테 호감있는거 눈치챘는데',
#  '엔프제가 선그었는데 또 들이대면 역효과야?',
#  'enfj 한테 관심식었는지 확인하는법 이건어떰',
#  '엔프제와 가장 잘 맞는 mbti',
#  '타 성격인데 엔프제가 가장 닮고 싶음',
#  '엔프제 남자랑 연락하는데',
#  '내가 잘하고 있는걸까',
#  '아무리봐도 친구사이인데',
#  '이거 호감표현인가요?',
#  '바람 펴본적 있거나 끌려본적 있음? ',
#  '엔프제 여자는 모르겠고 남자가 자기를 좋아하는지 헷갈린다면',
#  '소개팅했는데 잘 안 됐어ㅠㅠ',
#  '엔프제남사친한테 스며들거같아',
#  '너네 상대 mbti는 어떻게 아는거냐?',
#  '엔프제녀랑 밥먹는다',
#  '전남친 못잊는 엔프제녀를 좋아하는데',
#  '엔프제 남 헤어진지 3달째',
#  '영화보러 가자 하면 어때요?',
#  'ENFJ와 ISTP을 노래에 비유',
#  '엔프제랑 대화하다 보면 놀라는 점(?)',
#  '엔프제 허세부리는것같은거 기분탓일까',
#  '아 상처받아 ㅋㅋ',
#  '너희들',
#  '엔프제 다가가기 어렵당..',
#  'mbti는 그 누구든 환경에따라 언제든지 바뀐다',
#  '가벼운 스킨쉽 의미',
#  '엔프제들 타인 시선?의식 많이하는걸로아는데',
#  '엔프제들 애인이있어도 이성한테 한결같이 다정해?',
#  '슬퍼',
#  '엔프제가 사소한거 다 기억하는 게 흔한 일인가여',
#  '꼭 쓰고 싶었던 글을 쓸 수 있게 됐다.',
#  '엔프제의 귀엽다는 말은 호감표시야?',
#  '년 주기로 심심할때마다 mbti 검사하는데 신기하네',
#  '엔프제 남자들에게 질문해도 될까?? ',
# ...

# %%
len(enfj)
# Out:
# 7992

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in enfj)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ENFJ = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df1 = pd.DataFrame({"text":ENFJ, "type": 'ENFJ', "label": 0 }) 
df1
df1.to_csv("ENFJ.csv")

# %% [markdown]
# # ENTJ

# %%
for i in range(2,402):
    dc_id = "entj&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
        entj.append(title)

# %%
entj
# Out:
# ['주변에 사람 많은 게 좋은거냐?',
#  '엔티제이고 싶어하는 가짜 엔티제들이 이 갤에 상당히 많네',
#  '뭐래',
#  '다름을 인정받고 싶으면 씹새들아 욕심을 부리지마',
#  '짝사랑 상담 올리려다가',
#  '난 긁어부스럼 만드는 사람이 싫어.',
#  '남들이 나한테 맞춰준거라고 생각하니까 반성하게되네',
#  'ㅎㅇ 나 또왔다',
#  'J가 되기 위한 나의 노력',
#  'ENTJ의 고집에 대해서 명확히 설명해드림',
#  '연락 잘 안되는 여친 어떰?',
#  '사토시 나카모토의 마지막 채굴앱 NOAH. 사전예약',
#  '스스로 착하다고 하는 사람 조심해라',
#  '난 내 감정을 모르더라',
#  '엔티제 남자애를 좋아하는데 어떻게 해야해...?',
#  '찢재명 엔티제같지않냐?',
#  '나 중국 졸라싫어하는데',
#  '내가 좋아하는 사람 vs 나를 좋아하는 사람',
#  '엔트제는 진짜 모임장 잘함',
#  '엔티제는 자신의 마이너한 취향을 대놓고 티내진 않아도',
#  '엔티제남들아 질문',
#  '내가 너무 관종같아',
#  'esfj가 좆같은점',
#  'entj로 살면서 느끼는 점',
#  '나도 사업하면서 깜짝놀람',
#  '엔티제 친밀감 표현 어떻게 해?',
#  '요즘 드는 생각 부동의 1위',
#  '결혼까진 몰라도 자녀 계획은 절대 없음',
#  '고등학교 동창이 호빠 선수가 되었음',
#  '엔티제 특징 계획적 실행폭군 그런건 모르겠고',
#  '엔티제남 헤어졌는데 계속 시비걸어오는 거 왜그런거야',
#  '념글까지 엣티제 욕하는걸 봐선 자격지심 있구만 ㅋㅋ',
#  'entj 애인 존나 스윗해',
#  '니네 돈관리 어떤식으로함',
#  '대학생 삶이 존나 현타온다',
#  '엔티제아들 낳으면 해보고 싶은 것',
#  '나 isfp인데 entj가 나 귀여워 죽을려해',
#  '아래 글보고 내가 느끼는 entj estj차이점',
#  '사람 못 버리는 건 누가 더 심하냐?',
# ...

# %%
len(entj)
# Out:
# 5986

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in entj)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ENTJ = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df2 = pd.DataFrame({"text":ENTJ, "type":'ENTJ', "label": 1 }) 
df2
df2.to_csv("ENTJ.csv")

# %% [markdown]
# ## ESTJ

# %%
for i in range(2,402):
    dc_id = "estj&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
         
        estj.append(title)

# %%
estj
# Out:
# ['남자 키 vs 얼굴 뭐가 낫다고보냐',
#  '원래 계획이 있었는데',
#  '사토시 나카모토의 마지막 채굴앱 NOAH. 사전예약',
#  'estj와 entj가 합쳐진다면 어떤 일이 일어날까??',
#  'ESTJ남친 매력있어',
#  '엣티제랑 소개팅했는데',
#  '내가 너무 무겁게 생각하나?',
#  '엣티제 / 인프피 연인 존나 많은듯',
#  '엣티제들아 너네 아들러 좋아하냐?',
#  '나 인프피야..',
#  '엣티제 인스타 스토리 다 확인하는편?',
#  '파워계획적인 엣트제 완전사랑함',
#  '엣티제 전업주부 있냐?',
#  '미안한데 엣티제는 결혼안하는 유형이라 퐁퐁될일없음',
#  '제일 후회하는 일이 뭐임?',
#  'estj 썸녀가 시간약속 어기면 이거 까이는 시그널이지?',
#  '아니 어쩌자는 거야',
#  '보통 엣티제새끼들 아들래미가 학교집단폭력 당함',
#  '아니 엣티제새끼들은 왜 자기 일을 다른사람한테 떠넘기냐?',
#  '여기 올라오는 글들이 다 거짓인이유.',
#  '제가 ...',
#  '내가 딱 질색하는게',
#  '인프피시발련들 왜케 자주보임?',
#  '너네 짝사랑상대가 먼저 선톡오면 어때?',
#  '이런 ESTJ 많음?',
#  '부장이 estj 인데 나한테 일을 너무 많이 줘',
#  '으아 ㅅㅂ',
#  'estj남자 만나면서 아쉬운점 (철저히 본인위주)',
#  'estj의 인생 특별강의 - 운동편 ',
#  '나 nf인데 st 대하는 법 터득함',
#  'estj가 인생살아가는법',
#  'istj 념글 어떻게 생각함???',
#  'estj의 tmi',
#  'estj entj 뭐가 다름?',
#  'mbti 관심없을때 일임',
#  '엣티제는 촉 좋은 편이야?',
#  '엣티제녀들 결혼 관련 질문',
#  'estj 한테 똑똑하다고 칭찬들으면 진짜 똑똑한거냐',
#  '너네 대화 잘 하다가 만나잔 말에 답장 느려지는거',
#  '엣티제들은 다 혼밥하냐',
# ...

# %%
len(estj)
# Out:
# 6142

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in estj)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ESTJ = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df3 = pd.DataFrame({"text":ESTJ, "type":'ESTJ', "label": 2 }) 
df3

df3.to_csv("ESTJ.csv")

# %% [markdown]
# ## ESFJ

# %%
for i in range(2,402):
    dc_id = "esfj&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text   
        esfj.append(title)

# %%
esfj
# Out:
# ['너네무슨노래좋아해?',
#  '여기 갤주는 이분임? ',
#  '엣프제남 선물',
#  '너네 계속 선 넘게하는사람 싫어해?',
#  '너네들은 상대방이 간 보면 어떻게 대함?',
#  'ES가 mbti 중 탑임. 다 잡고있음',
#  'esfj 남자다 6일차 질문 천천히 받는다',
#  '엣프제는 거의 알림같아',
#  '엣프제 남자들은',
#  '엣프제이 공부 잘하는건 사바사임?',
#  'esfj는 왜케 성격이 좋은거냐',
#  '님들 장난끼많은  사람은 어떰?',
#  'isfj esfj 차이가 뭘까',
#  '안읽씹 2주만에 카톡읽었네..ㅋㅋ',
#  '검사할때마다 나오는 esfj남자인 내가 싫어하는 여자 특',
#  '니들 entj 만나본적 있음?',
#  'ESFJ인 바이든 대통령이 이번 방한때 준비한 선물',
#  '정식검사 해보니 인프피 나왔어ㅎㅎ',
#  '엠비티아이 갤은  ',
#  'EI 반반섞인 엣프제녀는 어떻게 꼬시죠?',
#  '잇픞남인데 너흰 맘없어도 1:1약속 잘잡니',
#  '내가좋아하는 사람이 엣프제인데 이거 나한테 호감있는거 맞나?',
#  '엣프제 성격 너무 좋고 착해',
#  'ES_J가 인맥 만드는거 젤 잘하는듯',
#  '썸을 그리고 연애를 시작하는 엣프제들아',
#  '너네 배려 짜증나',
#  '여기 대신 놀러와',
#  '우리 엄마가 ESFJ이신데 esfj 맞나 싶으심',
#  '잇프피는 이해하기 어렵다..  엣프제 남자 마음이 뭔지?',
#  '30대 초반남자 꼬시려면 어떻게하는게 좋을까?',
#  '니네한테 궁금한거 있음',
#  '썸타는 상태거나 사귀는연인이 장문카톡 보내주면 어때?',
#  'esfj 남자다 4일차 질문받는다.. 퇴근했으니 답장가능',
#  '내가 만나자고했는데 esfj가 너무 바쁘다고 연락옴',
#  'esfj 귀여운점ㅎ',
#  '잠들기전에 통화하는거 이거 관심맞지?',
#  '진짜 엣프제는 왜케 흘리고 다님?',
#  '나 질문있어...',
# ...

# %%
len(esfj)
# Out:
# 12776

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in esfj)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ESFJ = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df4 = pd.DataFrame({"text":ESFJ, "type":'ESFJ', "label": 3 }) 
df4

df4.to_csv("ESFJ.csv")

# %% [markdown]
# ## ENTP

# %%
for i in range(2,402):
    dc_id = "entp&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
         
        entp.append(title)

# %%
entp
# Out:
# ['둘이 맞짱뜨면 누가이김',
#  '얕은 지식만 많은 사람을 경계해야 하는 이유',
#  '난 가장 처음에 뭐였을까.',
#  '강용석 왜 사퇴 안한거지?',
#  '결국조니뎁이 이겼노ㅋㅋㅋ',
#  '미친집중력',
#  '높게 묶는걸 반묶음이라하나',
#  '얼굴 상반신 하반신을 끌리는 순대로 적으면',
#  '여자 머리 높게 묶는거',
#  '이중에 어떤 사람이 더 나아보임???',
#  'F여자 맞춤공략 최적화유형 ENFJ',
#  '여자 머리 높게 묶는걸 머라 그러지',
#  '여자머리 최고존엄',
#  '난 요즘 숏컷 여자가 예뻐보임',
#  '이때',
#  '숏컷 돼지 레즈비언 커플을 보면 인류애가 느껴진다',
#  '꼬부기 물뿌리개 < 존나 웃기지않음?ㅋㅋ',
#  '이상형 : 숏컷잘어울리는 톰보이',
#  'ㅈㄴ웃곀ㅋㅋㅋㅋㅋㅋ',
#  '경기도에서 패배한 이유',
#  '항상 무언가 결여가 된 연애를 한다',
#  '이상형',
#  '이상형:쥬지가 반응하는사람',
#  '불상레전드',
#  '내이상형MBTI',
#  '불교에서는 성적 욕망을 어떻게 다스렸는가',
#  '쉅끝나고집가면 과제제출까지 8시간남네',
#  '주기능 : 내향직관',
#  '3차, 부기능',
#  '저 갤러 볼때마다 좆같네..',
#  '자짤을 보니 더욱 슬프구나',
#  '와 이거 어디서 팔어',
#  '점심들묵었노',
#  '열등기능 : 외향감각',
#  '어젯밤에 어머니한테 드디어 결정사 밝혔다',
#  '여초에서 만든 섹스할때 여자가 좋아하는 말',
#  '러러로오옹로옹ㄹㄹㄹㄹㄹㄹㄹㄹ',
#  '좋아하는 여성이 생겼어요. 이를 어쩌죠. ',
#  '장첸 vs 강해상 어느쪽이 더 멋있는 빌런이냐',
#  '수학이 좃같은 이유',
#  '후 진정해 블루 워워',
#  '뮤.도.회를둬.집ㅇ어',
#  '섹스는 인간의 완성이 아니다.',
#  '너들자아실현은머야',
#  '이색기가 기만충인 이유',
#  '최종목표는 섹스아니냐',
# ...

# %%
len(entp)
# Out:
# 19935

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in entp)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ENTP = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df5 = pd.DataFrame({"text":ENTP, "type":'ENTP' ,"label": 4 }) 
df5

df5.to_csv("ENTP.csv")

# %% [markdown]
# ## ENFP

# %%
for i in range(2,402):
    dc_id = "enfp&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text

        enfp.append(title)

# %%
enfp
# Out:
# ['와 엔프피 진짜 어렵다',
#  '너넨 밸런스게임 바로바로 대답할 수 잇음??',
#  '좀 나이 있으면 인프제랑 헷갈림',
#  'enfp만 들어와보셈',
#  '엔프피녀 이런거 원래 다 하는거야?',
#  '엔프피남들아 니들도 연락 이따구로 하냐?',
#  '잘 지내고싶은거지 대시하는게 아니에요라고',
#  '눈웃음이 그렇게 오해사기좋은가',
#  '친구구함',
#  '인싸 엔프피들아',
#  '엔프피여친행동땜에 ㅈㄴ빡쳤는데 내가속좁은건지 판단좀',
#  'enfp 여사친 있는데',
#  '플러팅과 호감의 구분 가능해?',
#  '모고 끝나고 친구랑 고기먹을지 썸녀랑 영화보러 갈지 고민중',
#  '최근에 알게되서 좋아한 누나한테 읽씹당하는중 ㅜ',
#  '엥뿌삐남 카톡',
#  '엔프피 여잔데 궁금한거 답해드림',
#  '내 어린시절',
#  '엔픞남 원래 잘징징거려?',
#  'ENFP는 잘해줄수록 더 싫어하더라',
#  '서로 썸타다 상대 enfp녀가 마음이 식은 상태인데',
#  '엔프피는',
#  '엔프피 바람끼는 사바사임?',
#  '토끼.jpg',
#  '아니 이것도 단답이야?',
#  'ENFP 드립',
#  '애인이 남사친이랑 같은 킥보드 타고 오는걸 봤을 때 기분은?',
#  '엔프피 갑자기 어색해지는 이유가 뭐임?',
#  '아싸로 지내는 enfp 있음?',
#  '안녕 난 infp야 구경왔어',
#  '엔프피 왜케 사람이 착하냐..',
#  '애인있는 엔프피들아 너희 관심 없어도',
#  'Enfp들어 애인있는 사람한테 플러팅함?',
#  '엔픞남들 사람한테 빨리 질림??',
#  '잇팁녀',
#  '살기 싫다 see발',
#  '진짜 일하기 너무 힘들다...',
#  '자기가 읽씹해서 선그어놓고 만나면 왜 삐져있냐는 enfp누나 뭐임?',
#  '엔프피 처음 만나보는데 원래 이럼?',
#  'isfj인데 도와주실분..',
#  '엔프피 엔팁 사귀면 어때',
#  '챙겨주는 게 좋아 챙김 받는 게 좋아?',
# ...

# %%
len(enfp)
# Out:
# 13904

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in enfp)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ENFP = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df6 = pd.DataFrame({"text":ENFP, "type":'ENFP' ,"label": 5 }) 
df6

df6.to_csv("ENFP.csv")

# %% [markdown]
# ## ESTP

# %%
for i in range(2,402):
    dc_id = "estp&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
         
        estp.append(title)

# %%
estp
# Out:
# ['전여친이 더 잘나지면 뭔 생각듦',
#  '인프피년 또 감정쓰레기통 시동 걸길래 ',
#  '씹프피가 쓰는 엣팁이랑 안맞는 이유.txt',
#  '나 씹프피중에서도 씹프피거든?',
#  '엣팁인데 주량 0잔임',
#  '인프피만 연달아3명만났더니 정신병 올거같다',
#  '너네도 힘들때 잠수타냐?',
#  '정작 엔프피랑 제일 오래 만남',
#  '엣팁남친 심리 좀 알려줘',
#  '남자가 애교 부리면 존나 짜증나고 정 털리지 않음?',
#  '제발 도와줘',
#  '같은 유형 사람들 끼리 뭉쳐있대서 와봤더니 여긴 뭐 사람이 없냐',
#  '너희 소개팅갈때',
#  '지인들이랑 계속 어쩌다보니 하게 됨',
#  '병신들 이딴거 왜하냐',
#  '엣팁남한테 말리기 일보 직전ㅡㅡ하',
#  '개인적으로 난 엣티제가 젤 좆같더라',
#  '엣팁들이 진짜 멋있는 이유',
#  'estp istp 주구장창나오는데 뭐임',
#  '엣팁인데 첫사랑썰',
#  'NF랑 좆같이 안 맞는 점',
#  'estp인데 취향 엄청 독특함',
#  'S가 ST SF가 아닌 SP SJ로 나뉘는 이유래',
#  '나 estp 내친구 entp',
#  '너네 F 중에서 누구랑 제일 잘맞는거 같음?',
#  '엣팁이 짱이에요',
#  '번아웃 온 남자 엣팁임ㅂ',
#  'Estp 아닌거 같은데 하나하나 따져보면 여기임..',
#  'ESFP 여자 진짜 너무 사랑한다',
#  '재회 가능하다고 봄??',
#  '같은 엣팁이랑 썸타는ㄷㅔ 넘 조아',
#  '엣팁중에 문신 한 애들 많음?',
#  'estp 남자들에게 질문',
#  '엔티제들 넌씨눈이라서',
#  '엔프피는 다루기 쉬워서 좋음',
#  '연애보다 썸만타는게 좋은사람있냐??',
#  '곤지름 증상이 뭐야?',
#  '엣팁전남친 곤지름걸렸다고연락옴ㅋㅋㄱㄱㄱ',
#  '내 여동생은 썸만 오지게 타고 연애는 절대 안하더라',
#  'ESTP한테 까인 사람 다시한번 생각해보셈',
#  '본인 엣(엔)프피 남친이랑 연애중',
# ...

# %%
len(estp)
# Out:
# 14280

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in estp)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ESTP = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df7 = pd.DataFrame({"text":ESTP, "type":'ESTP'  ,"label": 6}) 
df7

df7.to_csv("ESTP.csv")

# %% [markdown]
# ## ESFP

# %%
for i in range(2,402):
    dc_id = "esfp&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
         
        esfp.append(title)

# %%
esfp
# Out:
# ['어 얘 엣프피다',
#  '너희 너무 어렵다',
#  '동성이면 잘맞는데 이성이면 esfp랑 안맞는유형',
#  '너네 사랑하지않는데 연애한적 있어 ?',
#  '흥쟁이 끼쟁이 엣프피들이 잘하지',
#  'esfp 는 흥이 많아서 술 취하고 스킨십 해주면',
#  'ESFP 랑 ENTP 은 참 재밌는 상성인거같아',
#  'ESFP는 알다가도 모르겠움',
#  '엣프피 커플',
#  '무지성 공감은 esfj enfj들이 잘하지',
#  'esfp 친구 고민',
#  'Esfp 기본 탑재= 이성에 대한 호감',
#  'Enfp 지나감',
#  'ESFP 보면 선택적 공감을 너무하더라',
#  'esfp 애들 플러팅 너무 어려워',
#  '너네도 좋아하는 사람 앞이면 뚝딱 거리냐',
#  'ㅋㅋㅋㅋ',
#  '아 오늘부터 진짜 존나 중요한데',
#  '나는 똑똑이야 전혀 멍청하지가 않어',
#  'ESFP랑 친하게 지내야 함',
#  '너네 똑똑한데 왜 겉으론 반대로 연기해',
#  '주기능이 Se라서 주변 빨리 알아챔',
#  'esfp는 좋아하는 사람이랑 카톡할때 말투 어떰?',
#  '잇프피남인데 엣프피녀에게 빠졌음',
#  'esfp 연락 스타일 왜이럼????',
#  '엣픞들이 들으면 기분 좋은 말 뭐야',
#  '엣프피랑 애인 관계가 되고 싶으면 이거 봐라. (긴 글 주의)',
#  '나만 이거 좀 정떨어짐?',
#  '엣픞이랑 가망 없는거 맞지?',
#  'esfp 인데 연락에 쿨한 사람 있음??',
#  '엣프피들 젤 잘맞는 mbti 뭐뭐 있어?',
#  '엣프피들은 맘에들면 선톡 잘함?',
#  '엣프피들아... 사랑에 빠져버린 인프제 좀 도와주라.....',
#  '엣프피는 애인 있냐고 물어보는거 의미 없지?',
#  '엔프피랑 엣프피랑 뭐가 더 걸레임?',
#  'esfp 여자 심리 좀',
#  'infp들 어떻게 생각함?',
#  '엣프피들 촉이라고 해야하나 감이라고 해야하나',
#  '엣프피 원래 졸라 사교적이야?',
# ...

# %%
len(esfp)
# Out:
# 15464

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in esfp)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ESFP = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df8 = pd.DataFrame({"text":ESFP, "type":'ESFP' ,"label": 7 }) 
df8

df8.to_csv("ESFP.csv")

# %% [markdown]
# ## ISTJ

# %%
for i in range(2,402):
    dc_id = "istj&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text

        istj.append(title)

# %%
istj
# Out:
# ['주변에서 잇티제 짝녀랑 어거지로 엮네',
#  '삶의 의욕이 없다니 개새끼야',
#  '에고그램',
#  'ㄹㅇ',
#  '맞는말인듯하다….',
#  '에고그램 결과',
#  '어제 잇티제 짝사랑 손절 어쩌구 이야기 한 앤데',
#  '에고그램 뼈 때린다.',
#  '나 estp여자다 istj 남자애 좀 괜찮은듯하다',
#  'UFO 뉴스같은거 최근에 엄청 뜨던데',
#  '에고그램 마저도 나보고 컴퓨터래',
#  '에고그램',
#  '어느 정도 맞긴 한데',
#  '무슨 말할지 뻔히 보이긴 했지만',
#  '나도 해봄',
#  '에고그램 개박치네..',
#  '잇티제남이 인스타 맞팔 일방적으로 끊었어',
#  '스스로를 몰아세우는거 어떻게 고치냐',
#  '상대방이 먼저 다다가거나 그러면 ',
#  '잇티제랑 가장 안맞는유형이 머야?',
#  '아 그나저나 타이밍 진짜 어이없네ㅋㅋ',
#  '아까 잇티제 짝사랑 손절 이야기 했던 타유형인데 ',
#  '잇티제가 짝사랑 마음 정리했는데 상대방이 눈치 없는 척 좋아하는 티 내면',
#  '너네 기준 상대방한테 선 긋는 행동들엔 어떤 게 있어?',
#  '애인한테만 f되는 잇티제 있니?',
#  'Intp랑 궁합 어떰',
#  '밑에거 이상한거 나왔어',
#  '나도 밑에거해봄',
#  '대충 잇티제처럼 나오네',
#  '인터넷검사는 가짜지?',
#  '밑에거 해보았음',
#  '해보실?',
#  '오래된 여사친과 연애 ㄱㄴ?',
#  '여기서 성별혐오글좀 쓰지 마라',
#  'ISTJ들은 좋아해도 당장 이어지지 않을 것 같으면',
#  '너네 유형한테 큰 실수를 해버린 거 같음',
#  '일단 취미에 만화보기가 있긴한데',
#  '교화됐음이 확실한 전과자랑 친구할 수 있음?',
#  '좋아하는 사람이 너넬 어떤사람으로 생각해줬으면 좋겠음?',
#  '나 mbti 잇티제같음?',
#  'ISTJ랑 결벽이랑 상관있냐?',
#  '인엔프피들 말이야',
#  '학습의 달인들에게 추천한다. 반박시 니말이 맞다',
# ...

# %%
len(istj)
# Out:
# 18835

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in istj)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ISTJ = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df9 = pd.DataFrame({"text":ISTJ, "type":'ISTJ'  ,"label": 8}) 
df9

df9.to_csv("ISTJ.csv")

# %% [markdown]
# ## ISFJ

# %%
for i in range(2,402):
    dc_id = "isfj&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
         
        isfj.append(title)

# %%
isfj
# Out:
# ['우리 가족 ㅁㅌㅊ?',
#  '잇프제가 생일선물 줬는데 궁금한거 있어',
#  '잇프제가 칼답할 정도면 정말 그 사람한테 신경 많이 쓰는거',
#  '카톡보내놓고 답장 늦으면 괜히말했나후회하고 걱정하는거 어떻게고쳐?ㅠ',
#  '잇프제 이렇게까지 해도 호감인거 모를수 있어?',
#  'Isfj남한테 궁금한게 스킨십을',
#  '잇프제 여자들 원래 남한테 빈말이라도 칭찬 많이해?',
#  '너네 톡할때 두서없이 새로운 주제 꺼내는 이유가 뭐야?',
#  '잇프제 호감없어도 선톡함?',
#  '잇프제 남자들아. 나 구썸녀인데, 다시 연락하고싶어. 해도될까?',
#  '잇프제들아 이거 썸이야??',
#  '짝남 속을 모르겠음',
#  '잇프제들아 너네들은 사랑해서 보내주는 경우도 있어?',
#  '잇붕이들아 너네 일상 연락 꾸준히 하는거 괜찮아 ?',
#  '잇프제가 둘이 만나자고 할 때까지 기다리는 게 맞냐',
#  'isfj한테 선톡 왔다 ㅜㅜ',
#  '몇일전에 진짜 처음으로 번호땄다고한사람인데',
#  '잇프제는 이런점이 문제야 바뀌도록 노력해야해',
#  '잇프제들때문에 미치겠셈',
#  '이거 여자가 호감있는거냐',
#  '사람 어디서 만나나',
#  '너네 정없어보인다는소리 잘들음?',
#  '잇프제둥이들 고마워',
#  '잇프제가 썸탈때 젤 많이하는 말',
#  '19) ㅅㅅ질문',
#  '자존심 강한 잇프제 상대하기 힘듦ㅠㅠ',
#  '버스안에서 울었던 경험 떠오름 갑자기 ㅋㅋ',
#  '친한친구들 mbti 뭐야?',
#  '가끔 헤어진 그녀가 떠오르네',
#  '잇프제들은 당일약속 거의 안잡지?',
#  '잇프제 특유의 소심함때문에 오해가 생겨서 멀어진 사람이 있으면',
#  '잇프제랑 밥약 잡았다',
#  '남 무시하는 사람 ',
#  '골라봐라',
#  '팔로우 할까말까',
#  'ISFJ 남자가 한달만에',
#  '진ㅉㅏ 내가 이상한가?',
#  '나 엔팁인데 잇프제남 너무 답답해서 멀어질려고 하다가',
# ...

# %%
len(isfj)
# Out:
# 16897

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in isfj)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ISFJ = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df10 = pd.DataFrame({"text":ISFJ, "type":'ISFJ'  ,"label": 9}) 
df10

df10.to_csv("ISFJ.csv")

# %% [markdown]
# ## INFJ

# %%
for i in range(2,402):
    dc_id = "infj&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
        infj.append(title)

# %%
infj
# Out:
# ['좋은 꿈 꿔',
#  '우울증 상담 받기로 결정했어',
#  '참정권이란 허상에 대해서... 라는 글에 대한 담론',
#  '경영 경제 전공한사람 있음?',
#  '인프제 챙겨주는거 좋아함?',
#  '난 같이 있는 사람에 따라 성격이 확 바뀌는 것 같다',
#  '참정권이란 허상에 대해서',
#  '심리상담 받으려고 하는데 질문 좀',
#  '현아 진짜 infj인가',
#  '방금 소름돋게 인프제 행동 나왔던게',
#  '인프제의 정치 성향은?',
#  'ESTJ 개극혐',
#  '여행갈 준비물들',
#  '수지 행복한척 들어본 애들있어?',
#  '와 군대 18개월 ㅈㄹ 크구나',
#  '자존감은 어떻게 올리는거야...?',
#  '갤과 이별한다... 잘 살아남고 가끔은 행복하자',
#  '너넨 눈길 한 번 안주는 사람',
#  '너네 DiSC 유형도 해봄?',
#  '인프제는',
#  '인프제가 타 유형보다 설렘에 초연한 건 어케 가능함?',
#  '내가 잘못된 걸까',
#  'infj 아이컨택에 의미를 두니?',
#  '한번 끄적여 봄',
#  '여자가 만약에 거의 이상형이다 싶게 마음에 드는데',
#  '저번에 고민있다고 INFJ님들 도와달라고 올린거 다음 이야기임..여전히.',
#  '애니어 맨날 바뀌는사람 나뿐임??',
#  '너네는 사랑이 두려워? 아님 연애가?',
#  '하기 싫은 대화는 어떻게 풀어가야 할까...',
#  '정말 순수한 궁금증인데',
#  '유형 궁금한 사람이 있는데',
#  '유흥 한번도 안해서 아쉬우면 한번씩 해',
#  '살아지니까 산다',
#  '편한사람한테만 예민한속내보이는거 죄책감든다',
#  '에니어그램 infj 1w9이면 ',
#  '오늘 저녁 ㅎㅎ',
#  '인프제 짝녀를 좋아하면서 욕심이 많이 없어진거같아',
#  '인프제남자',
#  'Fe가 질투에도 관여하냐?',
#  '나도 그냥 아무나 막 사귀거나 유흥 좀 즐겨볼 걸',
#  '인프제다운 고민있는데 들어줄 사람?',
# ...

# %%
len(infj)
# Out:
# 19919

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in infj)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
INFJ = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df11 = pd.DataFrame({"text":INFJ, "type":'INFJ'  ,"label": 10}) 
df11

df11.to_csv("INFJ.csv")

# %% [markdown]
# ## INTJ

# %%
for i in range(2,402):
    dc_id = "intj&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
         
        intj.append(title)

# %%
intj
# Out:
# ['여기 갤러리 왜이러냐',
#  '특히 여자가 남자한테 모솔 이러는거',
#  '처녀성 논쟁 다 좋은데',
#  '아다라는 개념자체가 어이없음',
#  '인티제녀랑 재회 꿈꾸면 안되냐?',
#  '여기 갤러리는 여자한테 칼자루줬냐?',
#  '일제강점기 아무 생각 없었는데 일본에 조선이 망한게 다행이라는 생각이 듦',
#  '야 이제 처녀순결 얘기 뇌절인데 그만하면 안되냐...? ㅠㅠ',
#  '계약직 직원 때문에 돌아버리겠음',
#  'INTJ가 가장 아다 많은 유형이긴할듯',
#  '상대방이 INTJ 여자인데 INTJ라고 알려진 특징이랑 너무 다름',
#  '3개월전 사키노바 테스트랑 비교',
#  'st의 장점은 뭐라고 생각함',
#  '비슷한 가치관 가진사람끼리 만나면 해결되잖아?',
#  '처녀처녀할거면 솔직히',
#  '이시대에 현실적으로 비처녀는 불가능하다?',
#  '이대나온 50짜리 노처녀있는데',
#  'pc충들이 좋아하는 캐릭터는?',
#  '앞으로 비처녀인 여자는 결혼할 생각 하면 안대',
#  '정보의 빠른 입출력 vs 창의력 ',
#  '선거하러가라.난 새벽에 했다',
#  '남자 34살이면 어린나이는 아닌가요?',
#  '인프제가 교실에서 조용히 책읽고있으면',
#  '성경이 ㅈㄴ 대단한이유',
#  '난 인티제 싫어!',
#  '손놈 거리는 가게 주인들',
#  '남자가 처녀 좋아하는건 본능임',
#  '여자도 아다남좋아함',
#  '최악이다',
#  '너네 사람에 대해서 기억잘함?',
#  '근데 솔직히 처녀인걸 확실히 어떻게 알아',
#  'F한테 논리적으로 얘기하면 나오는 말',
#  '처음찾는애들은 아다임?',
#  '솔직히 본능적으로 아는 이야기.',
#  '인티제 잊는법좀 알려줘라',
#  '여기 연령대가 어캐됨?',
#  '인티제한테 읽씹당했는데 선톡하면 ㅇㄸ',
#  '본인판단으로 순결카드 써버렸음 처녀찾는 새끼 욕하면 안됨',
#  '인티제 반강제로 술먹이고',
#  '문제가 생기고 해결 못하고 있을 때',
# ...

# %%
len(intj)
# Out:
# 19936

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in intj)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
INTJ = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df12 = pd.DataFrame({"text":INTJ, "type":'INTJ'  ,"label": 11}) 
df12

df12.to_csv("INTJ.csv")

# %% [markdown]
# ## ISTP

# %%
for i in range(2,402):
    dc_id = "istp&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
         
        istp.append(title)

# %%
istp
# Out:
# ['김철수 나와라~!',
#  '너희의 내면은 이런색이지 분발하고살자.',
#  '무현아 너 잇팁갤하는거 다안다',
#  '눈 보여주래서 보여주고 평생탈갤한다',
#  '로각좁ㅋㅋ',
#  '지유야 너 잇팁갤 하는거 다안다',
#  '여초에서 만든 추천 애무대화',
#  '게임/운동할때 좆같은점',
#  '동창 길에 만나서 아는척 했는데',
#  '본인 아바함',
#  '또 뭔 떡밥터짐?',
#  '내가 FPS 씹마니아임',
#  '아씨발 빤쓰만입고일하고싶네',
#  '드립력은 진짜 ㅋㅋㅋ',
#  '난 니들이 조아',
#  '아니시발 와타시의 사장은 어디갔나',
#  '난...너가 좋아...',
#  '좋다는 말이 핵심이었노',
#  '아니어디서 중ㄴ국냄새가나노 시발',
#  '야 그 머시기 다 필요없고',
#  '만약 위연의 자오곡계책을 허가해줫더라면 ㅇ,,,',
#  '난 정말 예쁜데/잘 생겼는데',
#  '재갈',
#  '너네직업없냐',
#  '이건어떨까',
#  '제갈씨는',
#  '나 극성 fps충',
#  '갤 오랜만에 왔는데 분위기 많이 바뀐거같음',
#  '여기는 에펙하는놈 없노?',
#  '제씨랑 갈씨도 제갈씨에서 파생덴거아닌 ㅇㅇ?',
#  '머리 정리하기 귀찮다',
#  '헤어지고 바로 다른 사람 만난적 있어?',
#  '중1국 특) ',
#  'PC로 갤하니까 댓글을 더 많이 양산할수 있네?',
#  '니들 만났던 이성 나이차이 몇살까지 만나봄?',
#  '감정적 교류를 하고싶다',
#  '하 자리도많은데',
#  '섹스',
#  '님아',
#  '장강에 와룡이 살아있었노 ㄹㅇ,,,',
#  '모르면 외워',
#  '523년만에 개백수 생활하니까 준내좋은ㅋㅋ',
#  '신성한 아주라를',
#  '게이선언이 답이라니까?',
#  '오해하게 만들지 마는게 중요',
#  '갤 시끌한 김에 잇팁남들아 질문',
#  '주딱달고 반년간',
#  '결론 뭘로 끝낼까',
#  '아 난 저런거 결론 내기까지 단체로 떠드는거 좋은데',
# ...

# %%
len(istp)
# Out:
# 19964

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in istp)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ISTP = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df13 = pd.DataFrame({"text":ISTP, "type":'ISTP'  ,"label": 12}) 
df13

df13.to_csv("ISTP.csv")

# %% [markdown]
# ## ISFP

# %%
for i in range(2,402):
    dc_id = "isfp&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
 
        isfp.append(title)

# %%
isfp
# Out:
# ['애니어그램 검사도 있던데',
#  'isfp 선톡이나 칼답에 관한 질문',
#  'isfp랑 지내니까',
#  '잇프피남 소개팅에서 직진했다가 차였다',
#  '떨려오는 별빛 반짝이는데 넌~ 어디를 보고 있는지~',
#  '잇프피 여자애가 번호따였다고 햇음',
#  '잇프피녀한테 비슷한 칭찬 계속 해줘도 돼?',
#  '이제 사람 만나는게 귀찮아',
#  '잇프제에도 올렸지만 여기에 또 올려볼게 ',
#  'isfp 썸남과의 관계 물어볼께',
#  '고맙다는 말 힘들어?',
#  '잇픞남들 일본 여자들과 잘 어울릴듯',
#  '긴급함 답좀 달아주라',
#  '잇프피 여자분들 질문드려요',
#  '친누나도 잇프피라네',
#  '잇프피 여자들께 질문드립니다',
#  '잇프피녀들아 너네 관심없는 사람한테도',
#  '전애인 생각에 심장이 꽉 조이는 느낌이 들어서',
#  '나 살짝 공주 스타일인거같음',
#  '잇픞갤 편한게 애들이 현실적임',
#  '진짜 isfp 너네들 너무 하지않냐?',
#  '상처준지 몰랐으면 몰랐던거임',
#  '인스타 피드추천에 여자',
#  'Isfp 남자 조언좀 ㅠ',
#  '귀찮음의 경지 어디까지 가봤냐?',
#  'Isfp들 착한편이긴 한거 같음 ',
#  '약간 오글거리는데 한번 화나면 눈돌아가',
#  '원빈은 isfp 인생의 최고봉이다',
#  '잇프피녀 포기할때인가..',
#  '진짜 바보같아 나',
#  '성격도 isfp에 외모까지도 여성스러운데',
#  '질투심 유발하고 허언증있는 여자는 거르는게 맞겠지??',
#  '감정 끊기면 이성이 돌아오는편',
#  '짝녀랑 내 베프랑 사귄다네....ㅎㅎ',
#  '수지 mbti가 isfp라고 함',
#  'isfp 여자들아 답변좀',
#  '잇프피 휴일 당일날or 전날 저녁에 보자그러면',
#  '상대가 은근하게 너랑 카톡하기 싫다는거 티내는 톡오면 어떻게해야함?',
#  '연애상담하러 오는 타유형이 항상 걱정하는 이유',
# ...

# %%
len(isfp)
# Out:
# 19946

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in isfp)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
ISFP = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df14 = pd.DataFrame({"text":ISFP, "type":'ISFP'  ,"label": 13}) 
df14

df14.to_csv("ISFP.csv")

# %% [markdown]
# ## INFP

# %%
for i in range(2,402):
    dc_id = "infp&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
         
        infp.append(title)

# %%
infp
# Out:
# ['긍까 인프피남들아',
#  'INFP 남들아',
#  '이잉부비갤',
#  '기분 나빠져서 책 안읽었어',
#  '오늘도못잘고같애',
#  '삼국지를 요약할게',
#  '미움의 꽃이 피네',
#  '밤이 싫다',
#  '뜬 구름 잡는것같은 이야기들이 재밌는듯',
#  '이중 누가가장 인프피남 관상임',
#  'ㄹㅇ궁금한거',
#  'Cuz I get a thousand hugs',
#  '인프피칭구',
#  '연애하고싶은데 좋아하는 사람이 없다',
#  '나는야 프롤레타리아!',
#  '빗물 사이로 라는 자작곡을 연주해보았습니다~',
#  '만약에 인프피녀가 좋아하는 남자한테',
#  '아 3일 운동 안했더니 ㅁㅊ 것 같네',
#  '인붕이 등산 갔다왔다ㅋㅋ어딘지 맞춰보셈',
#  '나 인푸피래',
#  '책 담고싶은대로 담으니까 8만원 나와',
#  '내일부터',
#  '나는 집돌인데 여행가는게 개 좋은데',
#  '중1때부터 대학교 1학년때까지 짝사랑했었음',
#  '영화보고싶은데',
#  '니들은 장암만은 걸리지 마라',
#  '인프피 짝사랑',
#  '호들갑 떠는 거 좋아해',
#  '여태 mbti 4번해봤는데 4번다 인프피더라',
#  '인프피가 좋아하면, 절대 티안낸다는게',
#  '인프피면 하루종일 들을수있는 노래',
#  '담배 피는 거 정말 좋지 않냐',
#  '우리 집에 손님왔어',
#  '인붕이 뚜껑열려',
#  '소중한 사람들이 힘들어하면 나도 영향을 강하게 받게 돼',
#  '지금 듣는',
#  'INFP 상처 받는 법',
#  '외로운가봐',
#  'mbti하면 INFP ENFP가 번갈아 나오던데',
#  '들켜버린건가',
#  '상큼한 ENFP 녀 짤',
#  'ESTP 남 짤',
#  '근데 INFP는 확실히 겉으론 표현 안 함.',
#  '본인 인프피가 느낀 장점과 단점',
#  '인프피는 위험한게 자기가 다 까발려짐',
#  '연애 좀 잘 아는 인프피 있냐',
#  '바퀴벌레를 보면 내가 생각나 ㅋㅋ',
# ...

# %%
len(infp)
# Out:
# 19968

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in infp)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
INFP = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df15 = pd.DataFrame({"text":INFP, "type":'INFP'  ,"label": 14}) 
df15

df15.to_csv("INFP.csv")

# %% [markdown]
# ## INTP

# %%
for i in range(2,402):
    dc_id = "intp_mbti&page=%d" %(i)
    
    url = f"https://gall.dcinside.com/mgallery/board/lists?id={dc_id}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "lxml")     
    article_list = soup.select(".us-post") #글 박스 전부 select
    
    for element in article_list:
        #글 박스를 하나씩 반복하면서 정보 추출
        title = element.select(".ub-word > a")[0].text
        
        intp.append(title)

# %%
intp
# Out:
# ['불건강 infj 유사조주빈 = 엔까',
#  'ㅉㅉ',
#  'Aㅏ니 그니깐 너 병신인거 다 안다니까?',
#  '좆스모폴리탄 : 친구보구싶오 뉴뉴',
#  '둘이 너무 잘어울려',
#  'intp은 정신병이 맞다',
#  '주재앙 저능아 새끼',
#  "'비추'라니 너무 극악무도 한거 아닌가 ㄷㄷ",
#  '나의 기말 과제가 좆 돼어가고 있다',
#  '생각해보니 악ㅇ디 근원이',
#  '말 안해도 애미뒤진거 아는데 굳이 왜 티냄?',
#  'Intp여자 무슨 카톡을 8시간만에 보내네',
#  '갤순위가 어떻개 228ㅋㅋㅋㅋ',
#  '오늘따라 섹스가 존나게 고프다',
#  '이중에 어떤 사람이 더 나아보임???',
#  '해장잘하고갑니다^느^...',
#  '크으~ 명대사다☺+',
#  '자바미 얼굴 박제한다',
#  '와!!와!!!미쳤다 미쳐부러부러☺+ 핵불닭수위 ㄷㄷ 공미모보소',
#  '와 진짜 개소름;;;;',
#  '와 엉딩이봐라 ㅗㅜㅑ.!! 눈밑점은 어떻고^느^.. 어휴 못참겠다.!!',
#  '프시케야 이거봐바',
#  '인팁갤 << 귀여운 이유',
#  '나도 탈갤한다',
#  '잘생기고 정조있고 순결하고 남리남리한 냄져들이나와서',
#  '나무위키 유형별문서 걍 근근웹 그 자체노',
#  '일베 저장소~ 일베 저장소에 왔어요~',
#  '요즘 한남들이 진짜 거세되긴 했구나',
#  '광석이 봤노',
#  '대체 뭔짓을 했길래',
#  '프시케님도 봉봉이처럼 레디컬패미임? ㅇㅇ',
#  '무슨 말을 해도 틀릴 거 같은 느낌',
#  '어떠카지어떠카지',
#  '인팁갤 여갤러 티어측정기 광석피셜 소통하고싶은 여갤러 1위',
#  '코키 엔까맞네',
#  '프시케님~ 광석이 4수 확정나면 공부하느라 바쁠테니',
#  '인팁은 성격인가',
#  '너네 빈츠 초콜렛 부분만 먹고 비스킷으로 분리 가능함?',
#  '내가 갤매니저면 불평존나하면서 탈갤한 새끼는',
#  '내가 싫어하는 인팁갤 고닉/유동닉 목록',
#  '상담료 받았어.',
# ...

# %%
len(intp)
# Out:
# 19936

# %%
# 리스트를 구분자 '@#'으로 설정한 뒤 문자열로 변환
str = '@#'.join(s for s in intp)

# 영어는 모두 소문자로 변환 
str = str.lower()

import re
# 정규표현식을 이용해서 완전한 한글, 숫자 띄어쓰기를 제외한 모든 부분 제거
# 구분자로 쓰일 @#도 제외
hangul = re.compile('[^ ㅋㅎㅅㅂㅠㅜ@#가-힣a-z+]')
restr = hangul.sub('', str) 

# 전처리한 데이터를 사전에 지정해둔 지정자 @#로 split후 리스트로 저장
INTP = restr.split('@#')



# 라벨링하며 데이터 프레임에 저장
df16 = pd.DataFrame({"text":INTP, "type":'INTP'  ,"label": 15}) 
df16

df16.to_csv("INTP.csv")

# %%
dcinside = len(ISTJ) + len(ISFJ) + len(ESTP) + len(ESFP) + len(INFJ) + len(INTJ) + len(ENFP) + len(ENTP) + len(ESTJ) + len(ESFJ) + len(ENFJ) + len(ENTJ) + len(ISTP) + len(ISFP) + len(INFP) + len(INTP)
dcinside
# Out:
# 251889
